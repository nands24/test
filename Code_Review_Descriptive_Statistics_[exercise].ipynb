# %% [markdown]
# # Code Review - Python Programming
# In this session, we will solve a few Python programming problems and review our work.

# %% [markdown]
# ### Quiz
# *The following question is similar to ones that can be asked in interviews at companies such as Dell for the Data Analyst role. Make sure to attempt this question! *
#
# Write code that displays the following pie chart. Please estimate the values for the *sizes* and *labels* parameters of `plt.pie()` from the image given below.
#
# **Hint:** `plt.pie()` has an *explode* parameter which allows one slice to be highlighted by segmenting it out of the pie as shown in the image. You can set *explode* for "Hogs" in your code to 0.2.
#
#
# ![pie1.jpg](data:image/jpeg;base64,...)

# %%
# Use this cell to import all the required packages and methods

# Data inferred from the provided pie chart
### CODE HERE ###

# Create the pie chart
### CODE HERE ###

# Display the chart
### CODE HERE ###

# %% [markdown]
# ### Quiz
# *The following question is similar to ones that can be asked in interviews at companies such as Fractal Analytics for the Analyst role. Make sure to attempt this question!*
#
# Given below are the weights, sugar levels and cholestrol of a class of people.
#
# ```
# data = {
#     "weight": [68.2, 72.5, 65.4, 74.1, 69.8, 70.5, 66.7, 73.2, 67.4, 71.6,
#                64.9, 75.3, 69.0, 72.0, 66.1, 74.8, 68.7, 70.9, 65.1, 73.6,
#                67.9, 71.2, 65.7, 74.4, 68.4],
#     "sugar levels": [90, 110, 95, 115, 100, 105, 92, 108, 97, 112,
#                      93, 118, 102, 109, 94, 116, 99, 106, 91, 110,
#                      98, 107, 96, 113, 101],
#      "cholesterol": [180, 195, 175, 200, 190, 185, 178, 197, 182, 193,
#                      170, 205, 188, 198, 176, 202, 181, 189, 173, 196,
#                      184, 191, 177, 203, 187]
# }
# ```
#
# Find the mean, median, variance, standard deviation, and the upper and lower quartiles of the weights of the class and also find the correlation between weight, sugar level and cholestrol. Represent the correlation as a heatmap.

# %%
# Use this cell to import all the required packages and methods

### CODE HERE ###
